# %% [markdown]
# <a href="https://www.kaggle.com/code/elnazalikarami/finding-data-references-make-data-count?scriptVersionId=259837033" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Finding Data References — macOS / VS Code (CPU)
#
# This version removes GPU-only dependencies (`vllm`, `auto-gptq`, `bitsandbytes`) and runs **on CPU** with `transformers`.
# - Create & activate a virtual env in VS Code Terminal:
#   ```bash
#   python3 -m venv .venv && source .venv/bin/activate
#   python -m pip install --upgrade pip
#   pip install transformers accelerate pandas numpy tqdm PyMuPDF
#   ```
# - If you have the dataset locally, set `BASE_DIR` below to the folder containing `train/PDF` and/or `test/PDF`. If you don't, you can still test the pipeline and text parsing with a few sample PDFs you place there.

# %%
# %pip install "transformers==4.43.3" "accelerate==0.33.0" torch pandas numpy tqdm

# %%
import sys, platform, importlib
mods = ["transformers","accelerate","pandas","numpy","tqdm","fitz"]
for m in mods:
    try:
        mod = importlib.import_module(m if m != "fitz" else "fitz")
        print(f"{m}: {getattr(mod, '__version__', 'OK')}")
    except Exception as e:
        print(f"{m}: NOT INSTALLED ({e})")
print("Python:", sys.version.split()[0], "| macOS:", platform.mac_ver()[0])
# Out:
# transformers: 4.43.3
# accelerate: 0.33.0
# pandas: 2.2.3
# numpy: 1.26.4
# tqdm: 4.67.1
# fitz: NOT INSTALLED (No module named 'fitz')
# Python: 3.11.13 | macOS:

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input/make-data-count-finding-data-references'): #'/kaggle/input/'
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/make-data-count-finding-data-references/sample_submission.csv
# /kaggle/input/make-data-count-finding-data-references/train_labels.csv
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_ece3.5260.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_chem.201902131.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_ece3.3985.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_ejoc.202000916.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_ece3.6144.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_2017jc013030.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_anie.201916483.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_chem.202001412.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_chem.202003167.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_chem.202001668.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_anie.202005531.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_ece3.5395.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_ece3.961.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_ejic.201900904.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_ece3.9627.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_ece3.4466.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_esp.5090.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_chem.202000235.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_chem.201903120.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_anie.202007717.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_ece3.6303.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_mp.14424.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_cssc.202201821.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_ece3.6784.xml
# /kaggle/input/make-data-count-finding-data-references/test/XML/10.1002_ecs2.4619.xml
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_cssc.202201821.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_ecs2.4619.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_ece3.9627.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_ejic.201900904.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_2017jc013030.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_ece3.3985.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_ejoc.202000139.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_chem.202001668.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_ece3.5395.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_ece3.6784.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_anie.202007717.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_chem.201903120.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_ece3.6303.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_chem.201902131.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_ecs2.1280.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_anie.201916483.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_esp.5058.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_ece3.5260.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_nafm.10870.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_ejoc.202000916.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_ece3.6144.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_ece3.961.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_anie.202005531.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_mp.14424.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_esp.5090.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_ece3.4466.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_chem.202001412.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_chem.202000235.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1002_chem.202003167.pdf
# /kaggle/input/make-data-count-finding-data-references/test/PDF/10.1007_jhep07(2018)134.pdf
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1590_1678-4685-gmb-2018-0055.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1021_jacs.2c06519.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s2056989015019891.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12881-019-0773-3.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3762_bjoc.8.42.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1038_s41597-023-02280-2.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1093_bib_bbab395.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12918-018-0564-z.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1017_s0007123423000601.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3133_fs20233046.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3133_ofr20231027.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1016_j.dib.2022.108797.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13104-018-4014-1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1021_acscentsci.1c01109.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12906-019-2769-0.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s1600536808011148.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1371_journal.pone.0117675.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12859-016-0938-4.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12864-018-5198-4.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12977-015-0204-2.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1080_14756366.2020.1740692.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1029_2018gl078007.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12885-018-4229-5.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1371_journal.pone.0139215.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1038_s41598-020-59839-x.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1016_j.ecolind.2021.107934.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1038_s41396-020-00885-8.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12870-019-1926-4.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1136_jitc-2021-003114.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.5194_essd-2023-187.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12870-020-02692-x.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1111_gcb.14974.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13046-018-0843-y.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_1752-153x-7-123.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12885-018-4314-9.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s2052252520013603.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1111_1365-2435.13569.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1039_d0sc02676j.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3390_rs4102923.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1109_access.2024.3385658.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13058-015-0618-8.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3389_feart.2023.1205211.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3389_fpls.2023.1160645.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13321-017-0246-7.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s1600536812024269.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12870-018-1332-3.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.5194_essd-12-1287-2020.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12864-015-2206-9.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_ece3.5260.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1039_d0sc03604h.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12885-017-3237-1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12859-018-2146-x.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1016_j.cpc.2024.109087.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.7554_elife.29944.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3390_inorganics7050058.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1128_spectrum.00422-24.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1021_acsomega.3c06074.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1371_journal.pone.0198382.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.20944_preprints202009.0353.v1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1371_journal.pone.0191086.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.12688_f1000research.13622.1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1038_sdata.2017.167.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_chem.201902131.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1038_s41467-019-10357-z.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_ece3.3985.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_ejoc.202000916.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13068-018-1316-4.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1111_bph.14747.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s1600536811003163.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1130_ges01387.1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.21203_rs.3.rs-3338732_v1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13024-018-0254-8.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1039_c9ra06638a.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s160053681103220x.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12920-020-00737-6.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1111_ddi.13161.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12864-020-6657-2.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.7717_peerj.12422.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3389_fcimb.2024.1292467.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3897_neobiota.82.87455.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1038_s41597-019-0101-y.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1371_journal.pone.0200041.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1093_beheco_arw167.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3133_ofr20231026.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_ece3.6144.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1039_d0sc02283g.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s11658-018-0120-2.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12864-019-6131-1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.5194_amt-15-3969-2022.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1534_g3.119.400401.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_2017jc013030.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1590_1516-3180.2018.0270071218.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12918-018-0620-8.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12918-015-0209-4.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12870-018-1542-8.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13326-019-0195-3.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1039_d1ee03696c.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3390_d13010019.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12859-018-2414-9.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1055_s-0039-1693681.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13059-020-1949-z.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_anie.201916483.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12859-018-2263-6.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12885-019-5681-6.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s1600536809014883.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s40169-019-0253-6.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_chem.202001412.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s1600536809022582.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12866-020-01863-y.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1128_JVI.01717-21.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3389_fcell.2020.618552.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_1471-244x-13-259.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s1600536810036299.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1029_2023wr035126.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3390_molecules23123199.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13024-018-0266-4.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s1600536811042164.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_chem.202003167.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1242_dev.138545.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12920-019-0628-y.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1111_1365-2656.12382.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.5194_acp-2021-570.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1590_1413-785220192703169516.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12859-016-1206-3.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1080_22221751.2020.1738277.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13068-017-0901-2.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1111_eva.12151.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1111_1365-2435.13431.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s2053229620003757.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_chem.202001668.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12879-019-3766-0.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1371_journal.pone.0093021.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s40793-015-0095-9.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12943-018-0878-x.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12866-019-1542-3.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13059-020-02048-6.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1007_s00382-022-06361-7.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12943-019-1017-z.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1016_j.dib.2023.109949.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1016_j.scitotenv.2024.171850.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_anie.202005531.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1155_2013_536562.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3897_zoologia.35.e23481.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13104-019-4127-1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13071-016-1359-y.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1145_3461702.3462538.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12859-020-3496-8.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.12688_f1000research.10556.1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13321-015-0110-6.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12868-018-0468-2.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13014-018-1166-z.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1039_d0sc01518k.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13321-017-0223-1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12935-020-01373-x.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13073-019-0674-2.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s2056989015010257.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12920-018-0379-1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s1600536809043700.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12916-019-1469-4.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s40168-018-0532-2.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1371_journal.pone.0170126.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3390_s19030479.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1617_s11527-023-02260-3.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1093_beheco_arad016.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1038_s41562-021-01247-w.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13643-018-0859-6.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.5194_acp-22-5701-2022.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12860-020-00261-6.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1093_beheco_arz101.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1080_21645515.2023.2189598.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.7554_elife.74937.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1111_1365-2656.12491.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12864-018-5054-6.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_ece3.5395.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12859-016-0904-1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1101_2022.02.10.480011.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s2056989016016819.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12859-017-1952-x.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1101_2022.07.21.501061.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12967-020-02311-1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1098_rspb.2015.1498.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1371_journal.pntd.0005385.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1111_eva.12446.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s2052252514012081.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1098_rsbl.2015.0113.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3390_molecules200917469.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1029_2022gl100473.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13059-019-1840-y.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1371_journal.pone.0262974.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12885-018-4768-9.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_ece3.961.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s40168-017-0338-7.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1039_c5sc01309g.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_ejic.201900904.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12868-019-0514-8.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3133_ofr20201035.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.21105_joss.04237.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12885-020-06724-5.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12920-019-0611-7.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s40478-018-0655-5.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1177_0018720820970751.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1038_s41597-022-01555-4.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13039-022-00631-z.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1098_rsos.170796.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12862-019-1388-1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.7554_eLife.72626.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12920-019-0646-9.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1371_journal.pone.0146274.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1038_s41598-021-85671-y.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12874-018-0583-x.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1111_acel.13089.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12882-019-1494-8.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1038_s41467-018-04041-x.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3390_s23094491.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_ece3.9627.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s40478-018-0561-x.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12864-018-4947-8.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12874-019-0829-2.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s2056989014026358.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1007_s00259-022-06053-8.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1029_2020jf005675.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12863-017-0513-7.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13148-019-0719-9.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s40851-018-0089-8.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13321-018-0298-3.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3897_zoologia.36.e32053.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12864-019-6099-x.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s11689-019-9287-8.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1140_epjc_s10052-018-6468-7.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1029_2021gl096173.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13148-018-0581-1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12859-020-3415-z.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.12688_f1000research.11698.1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1534_g3.119.400993.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s40170-020-00212-x.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13073-019-0709-8.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12870-019-2199-7.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_ece3.4466.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s2052252515023945.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.7554_elife.73695.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12920-018-0426-y.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12859-018-2036-2.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3390_s23177333.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1371_journal.pcbi.1011828.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13568-018-0680-6.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_esp.5090.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12974-020-01860-y.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1038_s41558-022-01301-z.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12920-018-0403-5.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12931-019-1001-6.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1038_s41437-020-0318-8.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12870-019-1904-x.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1080_15476286.2016.1232238.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1029_2023ea002840.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.5194_essd-2023-198.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1140_epjc_s10052-016-4366-4.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13071-018-2842-4.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.12688_f1000research.13852.1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13054-019-2488-4.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1007_s12559-020-09751-3.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13104-019-4058-x.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s1600536812014614.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1098_rsos.190841.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1016_j.molcel.2018.11.006.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13072-019-0322-5.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1007_s12263-014-0408-4.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1093_nar_gkp1049.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_chem.202000235.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_chem.201903120.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12934-018-1005-9.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13054-015-1052-0.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12884-018-1751-z.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3390_ijms12117360.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.7554_elife.42722.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1111_1365-2664.13136.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1111_gcb.13914.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13071-018-2964-8.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1212_wnl.0000000000006035.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1093_sysbio_syy011.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1016_j.ast.2022.107401.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12864-019-6324-7.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s1600536807066780.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1093_evolut_qpad206.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3390_microorganisms8121872.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1242_bio.035071.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12870-020-2295-8.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s40168-018-0550-0.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s40425-019-0730-x.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1111_2041-210x.12453.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1039_d0sc01197e.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s1600536812027390.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1098_rsos.210982.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13007-019-0403-2.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s160053681102201x.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1111_eva.12768.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s2056989020010658.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12870-019-1889-5.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12903-018-0656-6.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.12688_f1000research.13483.1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.7554_eLife.63194.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3390_v11060565.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3897_zookeys.500.9360.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_anie.202007717.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s1600536812046892.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12866-015-0509-2.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_ece3.6303.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13059-018-1557-3.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.12688_f1000research.4660.1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12864-019-5872-1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3390_molecules191017026.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13100-019-0153-8.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_mp.14424.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.5194_essd-2019-206.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12862-019-1509-x.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12913-018-3333-1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1111_ejn.13855.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s2052252515010271.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12862-015-0558-z.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1371_journal.pone.0096457.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1111_mec.16977.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1111_2041-210x.13817.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12870-019-1632-2.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_cssc.202201821.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3389_fchem.2019.00828.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_gb-2010-11-10-r101.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1371_journal.pone.0284951.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s2059798322005691.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1038_s41598-024-56373-y.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12859-017-1563-6.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1103_physrevresearch.4.023008.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1371_journal.pone.0159387.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13059-017-1200-8.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13059-019-1908-8.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13020-020-00307-z.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1038_ncomms11871.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.5194_gmd-13-335-2020.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s2052252515011665.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1073_pnas.2306723120.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1590_1414-431x20198292.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s1600536810047185.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1038_hdy.2015.99.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3133_cir1497.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1111_ddi.13153.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1371_journal.pone.0188323.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13059-019-1918-6.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13073-020-00727-4.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3897_bdj.7.e47369.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1107_s1600536812019885.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.17581_bp.2020.09104.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1371_journal.pone.0212669.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13059-019-1924-8.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1371_journal.pone.0070749.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13054-015-0738-7.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12859-016-0922-z.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3390_molecules25010053.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12863-019-0790-4.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1098_rspb.2015.2726.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1038_s41467-018-07681-1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1007_s00442-022-05201-z.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12933-019-0813-5.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12879-018-3065-1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13072-019-0285-6.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s40170-018-0185-4.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12915-018-0498-3.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.7554_elife.62329.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1111_njb.02077.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1590_s1677-5538.ibju.2019.0167.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1039_d2cc00847e.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3389_fmicb.2024.1456637.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13071-018-3084-1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.12688_f1000research.13064.1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1371_journal.pone.0253228.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.7717_peerj.10452.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.5194_acp-22-2769-2022.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1111_ggr.12517.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13059-019-1749-5.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1039_c9sc02930c.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_ece3.6784.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1002_ecs2.4619.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1038_s41598-017-15852-1.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1371_journal.pone.0220399.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.7717_peerj.11352.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.7717_peerj.13193.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12915-018-0584-6.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12870-020-02651-6.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.7554_elife.63455.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13071-018-3237-2.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1098_rsos.160417.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12967-019-2100-3.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1111_cas.12935.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.5194_gmd-12-4221-2019.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13068-018-1167-z.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s13068-018-1078-z.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1186_s12862-018-1213-2.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1371_journal.pone.0137181.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3762_bjoc.9.92.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1098_rspb.2015.0371.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.1016_j.jobe.2023.107105.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.5937_bnhmb1811227u.xml
# /kaggle/input/make-data-count-finding-data-references/train/XML/10.3390_molecules17077645.xml
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1371_journal.pone.0191086.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1140_epjc_s10052-018-6033-4.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1098_rsos.160417.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1002_cssc.202201821.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13046-018-0843-y.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1371_journal.pone.0284951.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1093_nar_gkp1049.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1107_s2059798322005691.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1038_hdy.2015.99.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.3897_jhr.96.111550.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_1980-5918.032.ao27.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12870-018-1332-3.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.5937_bnhmb1811227u.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1107_s2056989015019891.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12864-019-6099-x.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12870-020-02692-x.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1073_pnas.1705601114.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1534_g3.119.400993.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1080_0284186x.2019.1669817.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.3390_molecules17077645.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12870-019-1926-4.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13071-016-1359-y.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1029_2018gl078007.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1055_s-0039-1693681.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1002_ecs2.4619.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12859-017-1952-x.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1371_journal.pcbi.1011828.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1039_c9ra06638a.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_1981-86372019000243506.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12906-019-2769-0.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12913-018-3333-1.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_1983-21252019v32n324rc.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1111_2041-210x.12453.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1098_rsos.170796.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1002_ece3.9627.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.5194_essd-2023-187.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.12688_f1000research.11698.1.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s40168-018-0550-0.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1039_c5sc01309g.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12866-020-01863-y.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.3389_fpls.2023.1160645.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1098_rsos.190841.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1242_jeb.211466.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1098_rspb.2015.1498.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_1981-52712015v43n3rb20180090.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.3390_cryst2031058.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13039-022-00631-z.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1107_s2414314616007227.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1107_s2414314619012446.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12859-018-2146-x.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1038_s41598-017-15852-1.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1002_ejic.201900904.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12967-019-2100-3.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1080_07350015.2020.1766469.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1007_s00382-022-06361-7.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_s1677-5538.ibju.2019.0167.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.17815_jlsrf-2-58.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1107_s2056989016016819.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1093_bib_bbab395.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12864-019-6131-1.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_1809-9823.2007.10034.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12920-018-0403-5.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.5194_gmd-13-335-2020.pdf
# ...
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1111_1365-2656.12501.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1038_s41597-019-0101-y.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.5194_essd-12-1287-2020.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1111_evo.13972.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12870-019-2199-7.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_1980-5373-mr-2019-0338.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12859-016-1206-3.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1007_s10904-014-0054-8.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_1679-78255326.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.12688_f1000research.13622.1.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12943-019-1017-z.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12920-019-0628-y.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13104-018-4014-1.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1371_journal.pone.0200041.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13059-018-1557-3.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_1981-6723.06017.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1002_esp.5090.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12918-018-0564-z.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.3389_fevo.2023.1112519.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1111_1365-2664.13128.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.7717_peerj.13193.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.14358_pers.22-00039r2.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1007_s12559-020-09751-3.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.3133_ofr20231027.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_1678-4685-gmb-2018-0055.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12859-016-0938-4.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1080_0284186x.2020.1714721.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1371_journal.pone.0139215.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.3762_bjoc.9.92.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.12688_f1000research.13852.1.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13059-019-1924-8.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1016_j.jobe.2023.107105.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_1809-6891v21e-43578.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_1517-869220192505126869.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_1809-2950_19008627012020.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1051_e3sconf_202017220004.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.7717_peerj.12422.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.21203_rs.3.rs-3338732_v1.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12866-015-0509-2.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_1980-5373-mr-2018-0766.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12903-018-0656-6.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_1809-4430-eng.agric.v40n1p24-33_2020.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1128_JVI.01717-21.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12863-019-0790-4.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.14379_iodp.proc.390393.208.2024.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1039_d0sc02676j.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13568-018-0680-6.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1039_d1ee03696c.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12859-020-3496-8.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13054-015-0738-7.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_0104-4060.59642.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s40168-018-0532-2.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13059-019-1840-y.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12864-018-5198-4.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1111_1365-2435.13431.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12920-018-0426-y.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1038_s41597-023-02280-2.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.3389_fmicb.2024.1456637.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1016_j.fuel.2022.125768.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13068-017-0901-2.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1111_njb.02077.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1002_ece3.4466.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1107_s1600536812027390.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12920-020-00737-6.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1002_chem.202001412.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1140_epjc_s10052-018-6468-7.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13321-018-0298-3.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s40478-018-0655-5.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1145_3461702.3462538.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13100-019-0153-8.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1111_1365-2435.13087.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s11658-018-0120-2.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1128_spectrum.00422-24.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13059-020-02048-6.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.5194_gmd-12-4221-2019.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13321-017-0246-7.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1111_cas.12935.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1039_d0sc01518k.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1039_d0sc03604h.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1073_pnas.1915395117.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_1980-5918.033.ao15.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1016_j.dib.2022.108797.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1039_c9ce01020c.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1038_s41598-021-85671-y.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_2236-3459_83528.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1029_2021pa004379.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12866-019-1542-3.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1007_s00442-022-05201-z.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_0102-778632120150164.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1029_2019jg005297.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.3897_zoologia.36.e32053.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1007_jhep12(2018)117.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1111_1365-2656.12382.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1107_s1600536809022582.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1111_1365-2435.13569.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_2237-6089-2017-0134.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13072-019-0285-6.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12885-018-4768-9.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.3390_molecules25010053.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1098_rsos.210982.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1002_chem.202000235.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1111_mec.16977.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12870-019-1889-5.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.3897_zoologia.35.e23481.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.3390_molecules191017026.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13007-019-0403-2.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1140_epjds_s13688-018-0132-1.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13072-019-0322-5.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_1679-78255753.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1107_s2056989020010658.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.7554_eLife.63194.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1371_journal.pone.0262974.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12881-019-0773-3.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_1519-6984.192126.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1111_1365-2664.13446.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1107_s2052252520013603.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12885-018-4229-5.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13073-019-0674-2.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.20944_preprints202009.0353.v1.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1038_s41558-022-01301-z.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1021_acsomega.3c06074.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12864-018-5054-6.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1107_s1600536809043700.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13059-019-1918-6.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13071-018-3084-1.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.5194_tc-17-3617-2023.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.3390_v11060565.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1371_journal.pone.0159387.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1080_01621459.2019.1573732.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1007_s00382-012-1636-1.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13068-018-1078-z.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1016_j.ecolind.2021.107934.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1038_hdy.2014.75.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_0047-2085000000239.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.5194_amt-15-3969-2022.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12931-019-1001-6.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_1806-90882019000500004.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12916-019-1469-4.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13073-020-00727-4.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13058-015-0618-8.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1017_rdc.2022.19.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1007_s00259-022-06053-8.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1107_s2056989014026358.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12874-018-0583-x.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13068-018-1167-z.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1029_2023wr035126.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1002_chem.202003167.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1007_jhep07(2018)134.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12864-018-4947-8.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.3390_cryst9060301.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1039_d0sc02283g.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12967-020-02311-1.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1177_0018720820970751.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12885-017-3237-1.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1371_journal.pone.0093021.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.3389_feart.2023.1205211.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12859-020-3415-z.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1016_j.ast.2022.107401.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s13014-018-1166-z.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.17581_bp.2020.09104.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1029_2021gl096173.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1038_sdata.2017.167.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1111_ejn.13855.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_1752-153x-7-123.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1111_acel.13089.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12859-018-2036-2.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1590_1414-431x20198292.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1080_15476286.2016.1232238.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1371_journal.pntd.0005385.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1371_journal.pone.0170126.pdf
# /kaggle/input/make-data-count-finding-data-references/train/PDF/10.1186_s12864-019-5872-1.pdf

# %%
# !cp /kaggle/usr/lib/mdc_fine_grained_eval/mdc_fine_grained_eval_py.py ./mdc_fine_grained_eval.py

# %%
# !grep "def compute_metrics" mdc_fine_grained_eval.py
# Out:
# def compute_metrics(pred_df, gt_df):

# %%
# !grep "def " mdc_fine_grained_eval.py
# Out:
#     def __init__(
#     def __len__(self) -> int:
#     def __iadd__(self, other):  # in-place add
#     def __add__(self, other):
#     def score_set(self, cand: set, gold: set) -> None:
#     def precision(self) -> float:
#     def recall(self) -> float:
#     def f1(self) -> float:
#     def to_dict(self) -> Dict[str, float]:
# def compute_metrics(pred_df, gt_df):

# %%
import importlib.util

# Define path to the .py file
file_path = './mdc_fine_grained_eval.py'

# Load module from file path
spec = importlib.util.spec_from_file_location("mdc_fine_grained_eval", file_path)
mdc_eval = importlib.util.module_from_spec(spec)
spec.loader.exec_module(mdc_eval)

# Now, you can call compute_metrics like this:
# Example usage:
# metrics = mdc_eval.compute_metrics(pred_df, gt_df)

# %%
# %pip install pdfplumber
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.7-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 2.1 MB/s eta 0:00:00
# Collecting pdfminer.six==20250506 (from pdfplumber)
#   Downloading pdfminer_six-20250506-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.11/dist-packages (from pdfplumber) (11.2.1)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20250506->pdfplumber) (3.4.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20250506->pdfplumber) (44.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (2.22)
# Downloading pdfplumber-0.11.7-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.2 MB/s eta 0:00:00
# Downloading pdfminer_six-20250506-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 65.8 MB/s eta 0:00:00:00:0100:01
# Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 59.2 MB/s eta 0:00:00:00:01
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
# Successfully installed pdfminer.six-20250506 pdfplumber-0.11.7 pypdfium2-4.30.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, glob
from pathlib import Path

BASE_DIR = os.getenv('PDF_BASE_DIR', '/kaggle/input/make-data-count-finding-data-references')
use_test = os.getenv('USE_TEST', '0') == '1'
pdf_directory = os.path.join(BASE_DIR, 'test', 'PDF') if use_test else os.path.join(BASE_DIR, 'train', 'PDF')

print("BASE_DIR   :", os.path.abspath(BASE_DIR))
print("Using TEST :", use_test)
print("PDF folder :", os.path.abspath(pdf_directory))
print("Exists?    :", os.path.exists(pdf_directory))

# Count files (case-insensitive)
count_lower = len(glob.glob(os.path.join(pdf_directory, "*.pdf")))
count_upper = len(glob.glob(os.path.join(pdf_directory, "*.PDF")))
print("Found PDFs :", count_lower + count_upper, f"(lower:{count_lower} upper:{count_upper})")

# If zero, stop here and fix the path or add data
if not os.path.exists(pdf_directory):
    raise FileNotFoundError(f"Folder not found: {pdf_directory}")
if (count_lower + count_upper) == 0:
    raise FileNotFoundError(f"No PDFs found in {pdf_directory}. Check names/extensions and dataset structure.")
# Out:
# BASE_DIR   : /kaggle/input/make-data-count-finding-data-references
# Using TEST : False
# PDF folder : /kaggle/input/make-data-count-finding-data-references/train/PDF
# Exists?    : True
# Found PDFs : 524 (lower:524 upper:0)

# %%
import os, glob
from pathlib import Path
import pdfplumber
from tqdm import tqdm

BASE_DIR = os.getenv('PDF_BASE_DIR', '/kaggle/input/make-data-count-finding-data-references')
use_test = os.getenv('USE_TEST', '0') == '1'
pdf_directory = os.path.join(BASE_DIR, 'test', 'PDF') if use_test else os.path.join(BASE_DIR, 'train', 'PDF')

# Early checks
if not os.path.exists(pdf_directory):
    raise FileNotFoundError("Folder not found: {}".format(os.path.abspath(pdf_directory)))

num_lower = len(glob.glob(os.path.join(pdf_directory, "*.pdf")))
num_upper = len(glob.glob(os.path.join(pdf_directory, "*.PDF")))
if (num_lower + num_upper) == 0:
    raise FileNotFoundError("No PDFs found in {} (found lower:{}, upper:{})"
                            .format(os.path.abspath(pdf_directory), num_lower, num_upper))

# Case-insensitive glob
all_pdfs = sorted(list(Path(pdf_directory).glob("*.pdf")) +
                  list(Path(pdf_directory).glob("*.PDF")))

texts = []
print("Reading {} PDFs from: {}".format(len(all_pdfs), os.path.abspath(pdf_directory)))

for pdf_path in tqdm(all_pdfs, desc="Reading PDFs"):
    article_id = pdf_path.stem
    try:
        text_parts = []
        with pdfplumber.open(str(pdf_path)) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text() or ""
                page_text = page_text.lower()
                if "references" in page_text:
                    page_text = page_text.split("references")[0]
                    text_parts.append(page_text)
                    break
                else:
                    text_parts.append(page_text)
        texts.append((article_id, "".join(text_parts)))
    except Exception as e:
        # keep going, but log which file failed
        print("[WARN] Skipping {}: {}".format(pdf_path.name, e))
# Out:
# Reading 524 PDFs from: /kaggle/input/make-data-count-finding-data-references/train/PDF
# Reading PDFs: 100%|██████████| 524/524 [2:48:20<00:00, 19.28s/it]

# %%
#import os
#import re
#import fitz  # PyMuPDF
#import pandas as pd
#from pathlib import Path
#from tqdm.auto import tqdm
#from mdc_fine_grained_eval import compute_metrics

#Step 1: Read all PDFs and convert to text
#pdf_directory = "//kaggle/input/make-data-count-finding-data-references/test/PDF" \
                #if os.getenv('KAGGLE_IS_COMPETITION_RERUN') \
                #else "/kaggle/input/make-data-count-finding-data-references/train/PDF"
#all_data = []
#texts = []

#for filename in tqdm(os.listdir(pdf_directory), total=len(os.listdir(pdf_directory))):
    #if filename.endswith(".pdf"):
        #pdf_path = os.path.join(pdf_directory, filename)
         # Extract article_id from filename
        #article_id = filename.split(".pdf")[0]
        #doc = fitz.open(pdf_path)
        #text = ""
        #for page in doc:
            #page_text = page.get_text().lower()
            #if 'references' in page_text:
                #page_text = page_text.split("references")[0]
                #text += page_text
                #break
            #else:

                #text += page_text
            
        #doc.close()
        #texts.append((article_id, text))

# %%
import re

chunks = []

for article_id, text in texts:
    doi_matches = re.finditer(r"10\.\d{4}", text, re.IGNORECASE)
    for match in doi_matches:
        if match.group() in article_id: continue
        chunk = text[max(0, match.start() - 200): match.start() + 200]
        chunks.append((article_id, chunk))

# %%
import pickle

with open('chunks.pkl', 'wb') as file:
    pickle.dump(chunks, file)

# %%
len(chunks)
# Out:
# 1131

# %%
#import os
#os.environ["TRANSFORMERS_NO_TF"] = "1"   # avoid TF/Flax backends
#os.environ["TRANSFORMERS_NO_FLAX"] = "1"

#from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

#MODEL_ID = "sshleifer/tiny-gpt2"  # start tiny to verify
#tok = AutoTokenizer.from_pretrained(MODEL_ID)
#mdl = AutoModelForCausalLM.from_pretrained(MODEL_ID)
#gen = pipeline("text-generation", model=mdl, tokenizer=tok, device=-1)

#print(gen("Hello", max_new_tokens=20)[0]["generated_text"])

# %%
import os
os.environ["TRANSFORMERS_NO_TF"] = "1"   # avoid TF/Flax backends
os.environ["TRANSFORMERS_NO_FLAX"] = "1"

from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

# Load precomputed chunks
with open('chunks.pkl', 'rb') as file:
    chunks = pickle.load(file)

# Choose a small default model for CPU. Change via env HF_MODEL_ID if desired.
MODEL_ID = os.getenv("HF_MODEL_ID", "sshleifer/tiny-gpt2")
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
model = AutoModelForCausalLM.from_pretrained(MODEL_ID)
gen = pipeline("text-generation", model=model, tokenizer=tokenizer, device=-1)
# Out:
# 2025-09-03 17:07:54.532840: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756919274.571764     147 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756919274.583897     147 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# CPU sanity check for generation
prompt = "Explain quantum entanglement in simple terms."
out = gen(prompt, max_new_tokens=100)[0]["generated_text"]
print(out)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Explain quantum entanglement in simple terms.GySexualacious rented membership448448 deflect omega448 predators lined rubbing rented Late factors boilsSexualMostshows incarcerSexual Singapore courtyard workshops deflect653 workshops predatorsMini grandchildren incarcerGy� membershipshows incarceracious representations Dreams�acious courtyard Boone representations SingaporeshowsMost incarcer 236ived Television448Pros rubbing Tre Late courtyard TreGySexual rented boils Redux Wheelsshows grandchildren lined representationsacious factors Boone equate� Bend predators representationsacious Bend Dreams equate Reduxived Tre representations SingaporeMini lined predatorspublic omega Boone clearer653 Boonepublic rubbing Tre Wheels Dreams

# %%
#pip uninstall -y transformers tokenizers huggingface_hub accelerate
# !pip install --no-cache-dir "transformers==4.43.3" "accelerate==0.33.0" "tokenizers==0.19.1" "huggingface_hub==0.23.5"
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: transformers==4.43.3 in /usr/local/lib/python3.11/dist-packages (4.43.3)
# Requirement already satisfied: accelerate==0.33.0 in /usr/local/lib/python3.11/dist-packages (0.33.0)
# Requirement already satisfied: tokenizers==0.19.1 in /usr/local/lib/python3.11/dist-packages (0.19.1)
# Collecting huggingface_hub==0.23.5
#   Downloading huggingface_hub-0.23.5-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.43.3) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.43.3) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.43.3) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.43.3) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.43.3) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.43.3) (2.32.4)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.43.3) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.43.3) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate==0.33.0) (7.0.0)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from accelerate==0.33.0) (2.6.0+cu124)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub==0.23.5) (2025.5.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub==0.23.5) (4.14.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.43.3) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.43.3) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.43.3) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.43.3) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.43.3) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.43.3) (2.4.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==0.33.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==0.33.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==0.33.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==0.33.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==0.33.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==0.33.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==0.33.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==0.33.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==0.33.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==0.33.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==0.33.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==0.33.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==0.33.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==0.33.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==0.33.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==0.33.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==0.33.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.10.0->accelerate==0.33.0) (1.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.43.3) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.43.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.43.3) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.43.3) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.10.0->accelerate==0.33.0) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers==4.43.3) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers==4.43.3) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->transformers==4.43.3) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->transformers==4.43.3) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->transformers==4.43.3) (2024.2.0)
# Downloading huggingface_hub-0.23.5-py3-none-any.whl (402 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.8/402.8 kB 26.5 MB/s eta 0:00:00
# Installing collected packages: huggingface_hub
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.33.1
#     Uninstalling huggingface-hub-0.33.1:
#       Successfully uninstalled huggingface-hub-0.33.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 3.6.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.5.1 which is incompatible.
# datasets 3.6.0 requires huggingface-hub>=0.24.0, but you have huggingface-hub 0.23.5 which is incompatible.
# diffusers 0.34.0 requires huggingface-hub>=0.27.0, but you have huggingface-hub 0.23.5 which is incompatible.
# gradio 5.31.0 requires huggingface-hub>=0.28.1, but you have huggingface-hub 0.23.5 which is incompatible.
# peft 0.15.2 requires huggingface_hub>=0.25.0, but you have huggingface-hub 0.23.5 which is incompatible.
# Successfully installed huggingface_hub-0.23.5

# %%
import re, pickle, pandas as pd
from tqdm.auto import tqdm

prompt_template = """
You are given a piece of academic text. Your task is to:

1. Identify the single DOI citation string, if present.
2. Normalize it into its full URL format: https://doi.org/...
3. Classify the data associated with that DOI as:
    - "Primary": if the data was generated specifically for this study.
    - "Secondary": if the data was reused or derived from prior work.
    - "Not Relevant": if the DOI is part of the References section of a paper, does not refer to research data or is unrelated.

If no valid DOI is found, return an empty JSON object {}.

ONLY return ONE dictionary within JSON backticks with two keys:

```json
{"doi": "...", "type": "Primary|Secondary|Not Relevant"}
```
""".strip()

def build_prompt(article_id, chunk_text):
    return f"Article ID: {article_id}\n\nText:\n{chunk_text}\n\nInstructions:\n{prompt_template}\n\nReturn JSON only."

# Build prompts
prompts = [build_prompt(aid, txt) for aid, txt in chunks]

# Generate
responses = []
for p in tqdm(prompts, total=len(prompts)):
    try:
        txt = gen(p, max_new_tokens=512, do_sample=False)[0]["generated_text"]
    except Exception as e:
        txt = f"ERROR: {e}"
    responses.append(txt.lower())

with open('responses.pkl', 'wb') as file:
    pickle.dump(responses, file)
# Out:
#   0%|          | 0/1131 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
with open('responses.pkl', 'rb') as file:
    responses = pickle.load(file)

# %%
import json

json_block_pattern = r'```json\s*(.*?)\s*```'
citations = []

for (article_id, _), resp in zip(chunks, responses):
    try:
        match = re.search(json_block_pattern, resp, re.DOTALL)
        json_string = match.group(1).strip()
        parsed_json = json.loads(json_string)
        category = parsed_json["classification"].capitalize()
        if category in ['Primary', 'Secondary']:
            citations.append([article_id, parsed_json['doi'].replace("\u200b", "").replace("\n", ""), category])
    except Exception as e:
        # print(e)
        pass

# %%
submission = pd.DataFrame(citations, columns=['article_id', 'dataset_id', 'type'])

dataset_id_counts = submission['dataset_id'].value_counts()
frequent_dataset_ids = dataset_id_counts[dataset_id_counts >= 3].index
submission = submission[~submission['dataset_id'].isin(frequent_dataset_ids)].sort_values(by=["article_id", "dataset_id", "type"], ascending=True).drop_duplicates(subset=['article_id', 'dataset_id'])
submission['row_id'] = range(len(submission))

submission[['row_id', 'article_id', 'dataset_id', 'type']].to_csv("submission.csv", index=False)

# %%
pd.read_csv("submission.csv")
# Out:
# Empty DataFrame
# Columns: [row_id, article_id, dataset_id, type]
# Index: []

# %%
from sklearn.metrics import precision_recall_fscore_support

def compute_metrics(pred_df, reference_df):
    # assumes both DataFrames have ['article_id','dataset_id','type']
    y_true = reference_df['type'].values
    y_pred = pred_df.set_index('article_id').reindex(reference_df['article_id'])['type'].fillna("Missing").values

    p, r, f1, _ = precision_recall_fscore_support(y_true, y_pred, average="macro", zero_division=0)
    return {
        "ents_f1": f1,
        "ents_per_type": {
            "precision": p,
            "recall": r,
            "f1": f1
        }
    }

# %%
pred_df = pd.read_csv("submission.csv")
reference_df = pd.read_csv("/kaggle/input/make-data-count-finding-data-references/train_labels.csv")   # adjust path
reference_df = reference_df[reference_df['type'] != 'Missing'].reset_index(drop=True)

eval_dict = compute_metrics(pred_df, reference_df)
print("F1:", round(eval_dict['ents_f1'], 4))
print(json.dumps(eval_dict['ents_per_type'], indent=4))
# Out:
# F1: 0.0
# {
#     "precision": 0.0,
#     "recall": 0.0,
#     "f1": 0.0
# }
